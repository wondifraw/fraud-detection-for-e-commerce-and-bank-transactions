# %%
import sys
import os
sys.path.append(os.path.abspath('..'))
# %load_ext autoreload
# %autoreload 2

# %%
from src.shap_explain import run_all_shap_analyses

# This will generate and save SHAP plots for both datasets and both models
run_all_shap_analyses()
# Out:
# --- SHAP Analysis for Ecommerce ---
# c:\Users\W-HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\shap\explainers\_tree.py:583: UserWarning: LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray
#   warnings.warn(
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...
